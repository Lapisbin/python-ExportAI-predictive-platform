# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import warnings
warnings.filterwarnings('ignore')

# 한글 폰트 설정
plt.rc('font', family='Malgun Gothic')
# 마이너스 부호 깨짐 방지
plt.rc('axes', unicode_minus=False)

# 데이터 로드
df = pd.read_csv('data_integ_1.csv', parse_dates=['date'])
df.set_index('date', inplace=True)

# Lag 및 파생변수 생성
df['lag_1'] = df['export'].shift(1)
df['lag_2'] = df['export'].shift(2)
df['rolling_3'] = df['export'].rolling(window=3).mean().shift(1)
df['rolling_6'] = df['export'].rolling(window=6).mean().shift(1)  # 6개월 이동평균 추가
df['diff_1'] = df['export'].diff(1).shift(1)
df['month'] = df.index.month  # 월별 계절성 추가

# 결측치 처리
df = df.dropna()

# 특성과 타겟 분리
features = ['gdp_growth', 'korea_lead', 'brent_price', 'exchange_rate', 
           'gold_price', 'gas_price', 'usa_lead', 'china_lead',
           'lag_1', 'lag_2', 'rolling_3', 'rolling_6', 'diff_1', 'month']
X = df[features]
y = df['export']

# 데이터 스케일링
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# RNN을 위한 시퀀스 데이터 준비
def create_sequences(X, y, time_steps=3):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        Xs.append(X[i:(i + time_steps)])
        ys.append(y[i + time_steps])
    return np.array(Xs), np.array(ys)

time_steps = 3
X_seq, y_seq = create_sequences(X_scaled, y_scaled, time_steps)

# RNN 모델 구성
model = Sequential([
    LSTM(64, activation='relu', input_shape=(time_steps, X.shape[1]), return_sequences=True),
    Dropout(0.2),
    LSTM(32, activation='relu'),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(1)
])

# 모델 컴파일
model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae'])

# Early Stopping 설정
early_stopping = EarlyStopping(
    monitor='loss',
    patience=20,
    restore_best_weights=True,
    verbose=1
)

# 전체 데이터로 모델 학습
history = model.fit(X_seq, y_seq, 
                   epochs=200, 
                   batch_size=32, 
                   callbacks=[early_stopping],
                   verbose=1)

# 2025년 1월 예측을 위한 데이터 준비
last_sequence = X_scaled[-time_steps:]
last_sequence = last_sequence.reshape(1, time_steps, X.shape[1])

# 2025년 1월 수출량 예측
prediction_scaled = model.predict(last_sequence)
prediction_2025_01 = scaler_y.inverse_transform(prediction_scaled)[0][0]

print("\n2025년 1월 수출량 예측:")
print(f"예측 수출량: {prediction_2025_01:,.0f}")

# 과거 데이터와 예측값 시각화
plt.figure(figsize=(15, 6))

# 과거 실제 수출량
plt.plot(y.index, y, linestyle='-', label='실제 수출량', color='#1f77b4')

# 2025년 1월 예측값
future_date = pd.date_range(start=y.index[-1], periods=2, freq='M')[1]
plt.plot([future_date], [prediction_2025_01], marker='*', 
         markersize=15, linestyle='none', label='2025년 1월 예측', color='red')

plt.title('수출량 추세 및 2025년 1월 예측 (RNN 모델)', fontsize=15, pad=20)
plt.xlabel('년-월', fontsize=12)
plt.ylabel('수출량', fontsize=12)
plt.legend(prop={'size': 12})
plt.grid(True, alpha=0.3)

# x축 설정
plt.xticks(rotation=45)

# y축 포맷팅 (천 단위 쉼표)
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: format(int(x), ',')))

plt.tight_layout()
plt.show()

# 학습 손실 및 MAE 시각화
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Loss')
plt.title('모델 학습 손실 추이')
plt.xlabel('에포크')
plt.ylabel('손실')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['mae'], label='MAE')
plt.title('평균 절대 오차 추이')
plt.xlabel('에포크')
plt.ylabel('MAE')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# 변수 중요도 분석
importance = []
base_pred = model.predict(X_seq)
base_mse = np.mean((y_seq - base_pred) ** 2)

for feature_idx in range(X.shape[1]):
    X_temp = X_seq.copy()
    X_temp[:, :, feature_idx] = 0
    pred = model.predict(X_temp)
    mse = np.mean((y_seq - pred) ** 2)
    importance.append(mse - base_mse)

# 변수 중요도 시각화
plt.figure(figsize=(12, 6))
importance_df = pd.DataFrame({
    '특성': features,
    '중요도': importance
})
importance_df = importance_df.sort_values('중요도', ascending=True)

plt.barh(importance_df['특성'], importance_df['중요도'])
plt.title('RNN 모델 - 특성 중요도 (특성 제거 시 MSE 증가량)')
plt.xlabel('MSE 증가량')
plt.tight_layout()
plt.show()

# 모델 성능 지표 출력
# 전체 데이터에 대한 예측
all_sequences = create_sequences(X_scaled, y_scaled, time_steps)[0]
predictions_scaled = model.predict(all_sequences)
predictions = scaler_y.inverse_transform(predictions_scaled)
actual = scaler_y.inverse_transform(y_seq)

mse = mean_squared_error(actual, predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(actual, predictions)
r2 = r2_score(actual, predictions)

print("\n모델 성능 지표:")
print(f"Mean Squared Error: {mse:,.2f}")
print(f"Root Mean Squared Error: {rmse:,.2f}")
print(f"Mean Absolute Error: {mae:,.2f}")
print(f"R2 Score: {r2:.4f}")
# Out:
# Epoch 1/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3613 - mae: 0.5621
# Epoch 2/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2707 - mae: 0.4764
# Epoch 3/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2020 - mae: 0.4047
# Epoch 4/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0914 - mae: 0.2521
# Epoch 5/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0464 - mae: 0.1731
# Epoch 6/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0678 - mae: 0.2117
# Epoch 7/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0398 - mae: 0.1586
# Epoch 8/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0322 - mae: 0.1485
# Epoch 9/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0371 - mae: 0.1549
# Epoch 10/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0359 - mae: 0.1456
# Epoch 11/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0299 - mae: 0.1364
# Epoch 12/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0243 - mae: 0.1247
# Epoch 13/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0208 - mae: 0.1095
# Epoch 14/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0159 - mae: 0.0972
# Epoch 15/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0184 - mae: 0.1045
# Epoch 16/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0171 - mae: 0.0990
# Epoch 17/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0162 - mae: 0.0999
# Epoch 18/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0164 - mae: 0.0997
# Epoch 19/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0151 - mae: 0.0974
# Epoch 20/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0113 - mae: 0.0855
# Epoch 21/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0125 - mae: 0.0837
# Epoch 22/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0158 - mae: 0.0943
# Epoch 23/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0161 - mae: 0.0963
# Epoch 24/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0140 - mae: 0.0935
# Epoch 25/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0117 - mae: 0.0809
# Epoch 26/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0132 - mae: 0.0912
# Epoch 27/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0148 - mae: 0.0939
# Epoch 28/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0161 - mae: 0.0982
# Epoch 29/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0112 - mae: 0.0797
# Epoch 30/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0131 - mae: 0.0890
# Epoch 31/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0104 - mae: 0.0767
# Epoch 32/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0114 - mae: 0.0842
# Epoch 33/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0089 - mae: 0.0714
# Epoch 34/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0102 - mae: 0.0791
# Epoch 35/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0122 - mae: 0.0874
# Epoch 36/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0112 - mae: 0.0814
# Epoch 37/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0105 - mae: 0.0806
# Epoch 38/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0108 - mae: 0.0829
# Epoch 39/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0102 - mae: 0.0783
# Epoch 40/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0091 - mae: 0.0773
# Epoch 41/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0126 - mae: 0.0863
# Epoch 42/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0106 - mae: 0.0784
# Epoch 43/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0095 - mae: 0.0756
# Epoch 44/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0115 - mae: 0.0816
# Epoch 45/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0089 - mae: 0.0743
# Epoch 46/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0102 - mae: 0.0791
# Epoch 47/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0094 - mae: 0.0752
# Epoch 48/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0105 - mae: 0.0741
# Epoch 49/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0097 - mae: 0.0763
# Epoch 50/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0101 - mae: 0.0816
# Epoch 51/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0109 - mae: 0.0783
# Epoch 52/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0112 - mae: 0.0801
# Epoch 53/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0085 - mae: 0.0727
# Epoch 54/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0106 - mae: 0.0801
# Epoch 55/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0085 - mae: 0.0752
# Epoch 56/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0098 - mae: 0.0777
# Epoch 57/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0083 - mae: 0.0712
# Epoch 58/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0108 - mae: 0.0859
# Epoch 59/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0082 - mae: 0.0727
# Epoch 60/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0102 - mae: 0.0751
# Epoch 61/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0070 - mae: 0.0638
# Epoch 62/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0081 - mae: 0.0723
# Epoch 63/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0081 - mae: 0.0706
# Epoch 64/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0081 - mae: 0.0694
# Epoch 65/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0089 - mae: 0.0743
# Epoch 66/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0097 - mae: 0.0783
# Epoch 67/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0103 - mae: 0.0776
# Epoch 68/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0082 - mae: 0.0671
# Epoch 69/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0087 - mae: 0.0750
# Epoch 70/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0085 - mae: 0.0704
# Epoch 71/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0099 - mae: 0.0804
# Epoch 72/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0076 - mae: 0.0688
# Epoch 73/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0077 - mae: 0.0683
# Epoch 74/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0074 - mae: 0.0670
# Epoch 75/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0107 - mae: 0.0795
# Epoch 76/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0076 - mae: 0.0676
# Epoch 77/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0079 - mae: 0.0694
# Epoch 78/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0077 - mae: 0.0701
# Epoch 79/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0091 - mae: 0.0688
# Epoch 80/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0090 - mae: 0.0724
# Epoch 81/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0072 - mae: 0.0647
# Epoch 82/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0068 - mae: 0.0632
# Epoch 83/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0068 - mae: 0.0659
# Epoch 84/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0076 - mae: 0.0660
# Epoch 85/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0076 - mae: 0.0660
# Epoch 86/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0080 - mae: 0.0703
# Epoch 87/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0070 - mae: 0.0638
# Epoch 88/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0074 - mae: 0.0670
# Epoch 89/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0065 - mae: 0.0657
# Epoch 90/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0081 - mae: 0.0704
# Epoch 91/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071 - mae: 0.0654
# Epoch 92/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0066 - mae: 0.0635
# Epoch 93/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0087 - mae: 0.0698
# Epoch 94/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0082 - mae: 0.0698
# Epoch 95/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0074 - mae: 0.0666
# Epoch 96/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0069 - mae: 0.0649
# Epoch 97/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0064 - mae: 0.0623
# Epoch 98/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0072 - mae: 0.0660
# Epoch 99/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0078 - mae: 0.0681
# Epoch 100/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0074 - mae: 0.0702
# Epoch 101/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0069 - mae: 0.0641
# Epoch 102/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0076 - mae: 0.0656
# Epoch 103/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0062 - mae: 0.0628
# Epoch 104/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0063 - mae: 0.0605
# Epoch 105/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0072 - mae: 0.0665
# Epoch 106/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0067 - mae: 0.0638
# Epoch 107/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mae: 0.0679
# Epoch 108/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0078 - mae: 0.0671
# Epoch 109/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0063 - mae: 0.0643
# Epoch 110/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0084 - mae: 0.0660
# Epoch 111/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0075 - mae: 0.0620
# Epoch 112/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0077 - mae: 0.0681
# Epoch 113/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0061 - mae: 0.0612
# Epoch 114/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0078 - mae: 0.0659
# Epoch 115/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0059 - mae: 0.0602
# Epoch 116/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0075 - mae: 0.0641
# Epoch 117/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0058 - mae: 0.0616
# Epoch 118/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0055 - mae: 0.0566
# Epoch 119/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0066 - mae: 0.0604
# Epoch 120/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0074 - mae: 0.0651
# Epoch 121/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0057 - mae: 0.0573
# Epoch 122/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0050 - mae: 0.0557
# Epoch 123/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0059 - mae: 0.0598
# Epoch 124/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0067 - mae: 0.0657
# Epoch 125/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0063 - mae: 0.0634
# Epoch 126/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0064 - mae: 0.0639
# Epoch 127/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0061 - mae: 0.0608
# Epoch 128/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0063 - mae: 0.0619
# Epoch 129/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0064 - mae: 0.0605
# Epoch 130/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0071 - mae: 0.0673
# Epoch 131/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0062 - mae: 0.0641
# Epoch 132/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0050 - mae: 0.0546
# Epoch 133/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0057 - mae: 0.0567
# Epoch 134/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0065 - mae: 0.0620
# Epoch 135/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0077 - mae: 0.0713
# Epoch 136/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0058 - mae: 0.0588
# Epoch 137/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0050 - mae: 0.0542
# Epoch 138/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mae: 0.0612
# Epoch 139/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0059 - mae: 0.0592
# Epoch 140/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0054 - mae: 0.0588
# Epoch 141/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0067 - mae: 0.0629
# Epoch 142/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0079 - mae: 0.0702
# Epoch 143/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0065 - mae: 0.0622
# Epoch 144/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0056 - mae: 0.0573
# Epoch 145/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0067 - mae: 0.0637
# Epoch 146/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0061 - mae: 0.0591
# Epoch 147/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0065 - mae: 0.0629
# Epoch 148/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0063 - mae: 0.0645
# Epoch 149/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0055 - mae: 0.0562
# Epoch 150/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0052 - mae: 0.0534
# Epoch 151/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0049 - mae: 0.0552
# Epoch 152/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0061 - mae: 0.0573
# Epoch 153/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0061 - mae: 0.0648
# Epoch 154/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0052 - mae: 0.0580
# Epoch 155/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0063 - mae: 0.0628
# Epoch 156/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0062 - mae: 0.0621
# Epoch 157/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0063 - mae: 0.0626
# Epoch 158/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0059 - mae: 0.0588
# Epoch 159/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0061 - mae: 0.0618
# Epoch 160/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0058 - mae: 0.0603
# Epoch 161/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0049 - mae: 0.0520
# Epoch 162/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0068 - mae: 0.0621
# Epoch 163/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0059 - mae: 0.0620
# Epoch 164/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0043 - mae: 0.0521
# Epoch 165/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0058 - mae: 0.0602
# Epoch 166/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0049 - mae: 0.0521
# Epoch 167/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0051 - mae: 0.0565
# Epoch 168/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0055 - mae: 0.0571
# Epoch 169/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0052 - mae: 0.0588
# Epoch 170/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0066 - mae: 0.0630
# Epoch 171/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0052 - mae: 0.0570
# Epoch 172/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0047 - mae: 0.0566
# Epoch 173/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0051 - mae: 0.0559
# Epoch 174/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0052 - mae: 0.0563
# Epoch 175/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0061 - mae: 0.0620
# Epoch 176/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0048 - mae: 0.0542
# Epoch 177/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0058 - mae: 0.0579
# Epoch 178/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0064 - mae: 0.0661
# Epoch 179/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0043 - mae: 0.0506
# Epoch 180/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0056 - mae: 0.0601
# Epoch 181/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0053 - mae: 0.0564
# Epoch 182/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0048 - mae: 0.0548
# Epoch 183/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046 - mae: 0.0542
# Epoch 184/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0042 - mae: 0.0511
# Epoch 185/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0048 - mae: 0.0546
# Epoch 186/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0045 - mae: 0.0526
# Epoch 187/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0049 - mae: 0.0546
# Epoch 188/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0043 - mae: 0.0514
# Epoch 189/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0056 - mae: 0.0582
# Epoch 190/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0054 - mae: 0.0563
# Epoch 191/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0049 - mae: 0.0556
# Epoch 192/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0058 - mae: 0.0583
# Epoch 193/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0054 - mae: 0.0568
# Epoch 194/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - mae: 0.0510
# Epoch 195/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041 - mae: 0.0499
# Epoch 196/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0045 - mae: 0.0523
# Epoch 197/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0059 - mae: 0.0592
# Epoch 198/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0066 - mae: 0.0668
# Epoch 199/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0054 - mae: 0.0575
# Epoch 199: early stopping
# Restoring model weights from the end of the best epoch: 179.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
#
# 2025년 1월 수출량 예측:
# 예측 수출량: 990,602
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#
# 모델 성능 지표:
# Mean Squared Error: 1,036,369,476.30
# Root Mean Squared Error: 32,192.69
# Mean Absolute Error: 25,646.38
# R2 Score: 0.9200
