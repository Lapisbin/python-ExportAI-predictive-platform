# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM # LSTM 모델 사용
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')

# 한글 폰트 설정
plt.rc('font', family='Malgun Gothic')
# 마이너스 부호 깨짐 방지
plt.rc('axes', unicode_minus=False)

# 데이터 로드
df = pd.read_csv('data_integ.csv', parse_dates=['date'])
df.set_index('date', inplace=True)


# 타겟 변수와 피쳐 분리
X = df.drop(columns=['export_restored', 'export'])
y = df['export_restored']

# 데이터 정규화 // 타겟 변수 제외 스케일링이 되어있기 때문에 타겟 변수만 스케일링
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# 시계열 데이터 형태로 변환 (RNN 입력용)
def create_sequences(X, y, time_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        Xs.append(X.iloc[i:(i + time_steps)].values)
        ys.append(y[i + time_steps])
    return np.array(Xs), np.array(ys)

time_steps = 3  # 시퀀스 길이 설정
X_seq, y_seq = create_sequences(X, y_scaled, time_steps)

# 학습/테스트 데이터 분할 (80:20)
split_idx = int(len(X_seq) * 0.8)
X_train, X_test = X_seq[:split_idx], X_seq[split_idx:]
y_train, y_test = y_seq[:split_idx], y_seq[split_idx:]

# LSTM 모델 구성
model = Sequential([
    LSTM(256, activation='relu', input_shape=(time_steps, X.shape[1]), return_sequences=True),
    LSTM(128, activation='relu', return_sequences=True),
    LSTM(64, activation='relu', return_sequences=False), # 3차원 텐서를 그대로 Dense에 넣으면 ValueError 발생
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')

# 모델 학습
history = model.fit(X_train, y_train, 
                   epochs=200, 
                   batch_size=16,
                   validation_split=0.2,
                   verbose=1)

# 예측 수행
preds_scaled = model.predict(X_test)

# 예측값 역정규화 // 스케일링 해줬던 값을 원본으로 복구
preds = scaler_y.inverse_transform(preds_scaled)
y_test_original = scaler_y.inverse_transform(y_test)

# 모델 성능 평가
def get_reg_eval(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"MAE: {mae:.4f}, RMSE: {rmse:.4f}, R2: {r2:.4f}")

get_reg_eval(y_test_original, preds)

# ---------------------- 여기서부터는 시각화 코드 ----------------------------
# 예측 결과와 실제 값을 포함한 DataFrame 생성
results_df = pd.DataFrame({
    '실제 수출량': y_test_original.flatten(),
    '예측 수출량': preds.flatten()
}, index=df.index[split_idx+time_steps:])

# 소수점 반올림 및 정수형 변환
results_df = results_df.round(0).astype(int)

# x축 눈금용 날짜 리스트 생성
dates = results_df.index.strftime('%Y-%m')

# 실제값과 예측값 시각화
plt.figure(figsize=(15, 6))

plt.plot(range(len(dates)), results_df['실제 수출량'], 
         marker='o', linestyle='-', label='실제 수출량', color='#1f77b4')
plt.plot(range(len(dates)), results_df['예측 수출량'], 
         marker='o', linestyle='--', label='예측 수출량', color='#ff7f0e')

# 실제값과 예측값 텍스트 표시
for i in range(len(dates)):
    real_val = results_df['실제 수출량'].iloc[i]
    pred_val = results_df['예측 수출량'].iloc[i]
    
    if real_val >= pred_val:
        plt.text(i, real_val, f'{real_val:,.0f}', 
                 verticalalignment='bottom', 
                 horizontalalignment='center',
                 fontsize=8)
        plt.text(i, pred_val, f'{pred_val:,.0f}', 
                 verticalalignment='top', 
                 horizontalalignment='center',
                 fontsize=8)
    else:
        plt.text(i, pred_val, f'{pred_val:,.0f}', 
                 verticalalignment='bottom', 
                 horizontalalignment='center',
                 fontsize=8)
        plt.text(i, real_val, f'{real_val:,.0f}', 
                 verticalalignment='top', 
                 horizontalalignment='center',
                 fontsize=8)

# 그래프 스타일링
plt.title('테스트 세트: 실제 수출량 vs 예측 수출량 (LSTM)', fontsize=15, pad=20)
plt.xlabel('년-월', fontsize=12)
plt.ylabel('수출량', fontsize=12)
plt.legend(prop={'size': 12})
plt.grid(True, alpha=0.3)

# x축 설정
plt.xticks(range(len(dates)), dates, rotation=45)

# y축 포맷팅 (천 단위 쉼표)
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: format(int(x), ',')))

plt.tight_layout()
plt.show()

# 결과 출력
print("\n실제값과 예측값 비교 (LSTM):")
print(results_df.to_string(float_format=lambda x: '{:,.0f}'.format(x)))
# Out:
# Epoch 1/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0653 - val_loss: 0.0224
# Epoch 2/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0491 - val_loss: 0.0083
# Epoch 3/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0279 - val_loss: 0.0059
# Epoch 4/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0185 - val_loss: 0.0359
# Epoch 5/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0166 - val_loss: 0.0147
# Epoch 6/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0183 - val_loss: 0.0143
# Epoch 7/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0247 - val_loss: 0.0274
# Epoch 8/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0110 - val_loss: 0.0618
# Epoch 9/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0130 - val_loss: 0.0889
# Epoch 10/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0216 - val_loss: 0.1140
# Epoch 11/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0126 - val_loss: 0.1348
# Epoch 12/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0160 - val_loss: 0.1656
# Epoch 13/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0204 - val_loss: 0.1554
# Epoch 14/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0120 - val_loss: 0.1715
# Epoch 15/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0084 - val_loss: 0.1931
# Epoch 16/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0150 - val_loss: 0.1772
# Epoch 17/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0096 - val_loss: 0.1354
# Epoch 18/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0095 - val_loss: 0.1461
# Epoch 19/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0135 - val_loss: 0.1955
# Epoch 20/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0097 - val_loss: 0.1662
# Epoch 21/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0098 - val_loss: 0.1487
# Epoch 22/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0073 - val_loss: 0.1225
# Epoch 23/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0090 - val_loss: 0.1887
# Epoch 24/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0113 - val_loss: 0.1406
# Epoch 25/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0115 - val_loss: 0.1646
# Epoch 26/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0181 - val_loss: 0.1406
# Epoch 27/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0085 - val_loss: 0.1254
# Epoch 28/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0076 - val_loss: 0.1241
# Epoch 29/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0102 - val_loss: 0.1242
# Epoch 30/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0120 - val_loss: 0.0668
# Epoch 31/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0109 - val_loss: 0.0550
# Epoch 32/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0079 - val_loss: 0.0898
# Epoch 33/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0066 - val_loss: 0.0374
# Epoch 34/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0167 - val_loss: 0.0573
# Epoch 35/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0120 - val_loss: 0.0452
# Epoch 36/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0152 - val_loss: 0.0228
# Epoch 37/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0077 - val_loss: 0.0444
# Epoch 38/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0060 - val_loss: 0.0117
# Epoch 39/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0070 - val_loss: 0.0154
# Epoch 40/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0105 - val_loss: 0.0069
# Epoch 41/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0112 - val_loss: 0.0081
# Epoch 42/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0156 - val_loss: 0.0057
# Epoch 43/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0075 - val_loss: 0.0051
# Epoch 44/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0076 - val_loss: 0.0082
# Epoch 45/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0099 - val_loss: 0.0067
# Epoch 46/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0103 - val_loss: 0.0073
# Epoch 47/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0136 - val_loss: 0.0056
# Epoch 48/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0078 - val_loss: 0.0069
# Epoch 49/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0087 - val_loss: 0.0078
# Epoch 50/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0114 - val_loss: 0.0088
# Epoch 51/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0077 - val_loss: 0.0108
# Epoch 52/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0070 - val_loss: 0.0116
# Epoch 53/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0045 - val_loss: 0.0092
# Epoch 54/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0062 - val_loss: 0.0121
# Epoch 55/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0072 - val_loss: 0.0125
# Epoch 56/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0067 - val_loss: 0.0120
# Epoch 57/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0043 - val_loss: 0.0093
# Epoch 58/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0078 - val_loss: 0.0143
# Epoch 59/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0164 - val_loss: 0.0127
# Epoch 60/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0104 - val_loss: 0.0077
# Epoch 61/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0214 - val_loss: 0.0054
# Epoch 62/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0076 - val_loss: 0.0047
# Epoch 63/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0073 - val_loss: 0.0077
# Epoch 64/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0154 - val_loss: 0.0047
# Epoch 65/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0053 - val_loss: 0.0046
# Epoch 66/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0161 - val_loss: 0.0058
# Epoch 67/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0135 - val_loss: 0.0050
# Epoch 68/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0110 - val_loss: 0.0058
# Epoch 69/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0083 - val_loss: 0.0060
# Epoch 70/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0063 - val_loss: 0.0064
# Epoch 71/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0096 - val_loss: 0.0073
# Epoch 72/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0083 - val_loss: 0.0080
# Epoch 73/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0038 - val_loss: 0.0083
# Epoch 74/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0060 - val_loss: 0.0089
# Epoch 75/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0136 - val_loss: 0.0094
# Epoch 76/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0048 - val_loss: 0.0070
# Epoch 77/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0042 - val_loss: 0.0082
# Epoch 78/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0041 - val_loss: 0.0086
# Epoch 79/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0039 - val_loss: 0.0084
# Epoch 80/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0039 - val_loss: 0.0088
# Epoch 81/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0029 - val_loss: 0.0100
# Epoch 82/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0029 - val_loss: 0.0112
# Epoch 83/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0034 - val_loss: 0.0112
# Epoch 84/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0041 - val_loss: 0.0112
# Epoch 85/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0041 - val_loss: 0.0114
# Epoch 86/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0058 - val_loss: 0.0122
# Epoch 87/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0085 - val_loss: 0.0134
# Epoch 88/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0039 - val_loss: 0.0140
# Epoch 89/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0062 - val_loss: 0.0110
# Epoch 90/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0046 - val_loss: 0.0100
# Epoch 91/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0056 - val_loss: 0.0099
# Epoch 92/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0083 - val_loss: 0.0083
# Epoch 93/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0062 - val_loss: 0.0071
# Epoch 94/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0061 - val_loss: 0.0080
# Epoch 95/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0060 - val_loss: 0.0082
# Epoch 96/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0038 - val_loss: 0.0083
# Epoch 97/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0058 - val_loss: 0.0098
# Epoch 98/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0031 - val_loss: 0.0104
# Epoch 99/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0035 - val_loss: 0.0117
# Epoch 100/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0031 - val_loss: 0.0121
# Epoch 101/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0018 - val_loss: 0.0122
# Epoch 102/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0023 - val_loss: 0.0141
# Epoch 103/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0040 - val_loss: 0.0150
# Epoch 104/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0024 - val_loss: 0.0154
# Epoch 105/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0021 - val_loss: 0.0153
# Epoch 106/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0020 - val_loss: 0.0165
# Epoch 107/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0017 - val_loss: 0.0197
# Epoch 108/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0045 - val_loss: 0.0193
# Epoch 109/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0021 - val_loss: 0.0171
# Epoch 110/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0022 - val_loss: 0.0175
# Epoch 111/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0019 - val_loss: 0.0187
# Epoch 112/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0016 - val_loss: 0.0211
# Epoch 113/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0024 - val_loss: 0.0228
# Epoch 114/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0029 - val_loss: 0.0173
# Epoch 115/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0065 - val_loss: 0.0169
# Epoch 116/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0061 - val_loss: 0.0185
# Epoch 117/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0036 - val_loss: 0.0163
# Epoch 118/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0039 - val_loss: 0.0164
# Epoch 119/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0031 - val_loss: 0.0190
# Epoch 120/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0018 - val_loss: 0.0279
# Epoch 121/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0023 - val_loss: 0.0314
# Epoch 122/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0017 - val_loss: 0.0324
# Epoch 123/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0014 - val_loss: 0.0339
# Epoch 124/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0017 - val_loss: 0.0413
# Epoch 125/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0014 - val_loss: 0.0365
# Epoch 126/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0012 - val_loss: 0.0344
# Epoch 127/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0014 - val_loss: 0.0374
# Epoch 128/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0013 - val_loss: 0.0369
# Epoch 129/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0011 - val_loss: 0.0329
# Epoch 130/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0012 - val_loss: 0.0348
# Epoch 131/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0013 - val_loss: 0.0292
# Epoch 132/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0022 - val_loss: 0.0306
# Epoch 133/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0019 - val_loss: 0.0351
# Epoch 134/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0015 - val_loss: 0.0287
# Epoch 135/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0020 - val_loss: 0.0386
# Epoch 136/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0019 - val_loss: 0.0326
# Epoch 137/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0012 - val_loss: 0.0321
# Epoch 138/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0010 - val_loss: 0.0454
# Epoch 139/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0012 - val_loss: 0.0419
# Epoch 140/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0010 - val_loss: 0.0357
# Epoch 141/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0010 - val_loss: 0.0435
# Epoch 142/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0012 - val_loss: 0.0449
# Epoch 143/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 8.1384e-04 - val_loss: 0.0383
# Epoch 144/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0011 - val_loss: 0.0379
# Epoch 145/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 9.3351e-04 - val_loss: 0.0366
# Epoch 146/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 9.4016e-04 - val_loss: 0.0339
# Epoch 147/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.1464e-04 - val_loss: 0.0378
# Epoch 148/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 8.1865e-04 - val_loss: 0.0404
# Epoch 149/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.8098e-04 - val_loss: 0.0370
# Epoch 150/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.9673e-04 - val_loss: 0.0352
# Epoch 151/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 5.9420e-04 - val_loss: 0.0444
# Epoch 152/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 7.9485e-04 - val_loss: 0.0456
# Epoch 153/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 9.8067e-04 - val_loss: 0.0398
# Epoch 154/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 7.0853e-04 - val_loss: 0.0430
# Epoch 155/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 9.0054e-04 - val_loss: 0.0412
# Epoch 156/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 7.2072e-04 - val_loss: 0.0420
# Epoch 157/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.8577e-04 - val_loss: 0.0386
# Epoch 158/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 7.1503e-04 - val_loss: 0.0391
# Epoch 159/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 5.0037e-04 - val_loss: 0.0392
# Epoch 160/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 6.6890e-04 - val_loss: 0.0381
# Epoch 161/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.0076e-04 - val_loss: 0.0391
# Epoch 162/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.8738e-04 - val_loss: 0.0406
# Epoch 163/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.7377e-04 - val_loss: 0.0430
# Epoch 164/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.7597e-04 - val_loss: 0.0428
# Epoch 165/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.8299e-04 - val_loss: 0.0454
# Epoch 166/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 6.2500e-04 - val_loss: 0.0402
# Epoch 167/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.9475e-04 - val_loss: 0.0440
# Epoch 168/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 5.8802e-04 - val_loss: 0.0491
# Epoch 169/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.2598e-04 - val_loss: 0.0377
# Epoch 170/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.3006e-04 - val_loss: 0.0461
# Epoch 171/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.4319e-04 - val_loss: 0.0430
# Epoch 172/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.8063e-04 - val_loss: 0.0344
# Epoch 173/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 6.4606e-04 - val_loss: 0.0598
# Epoch 174/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 4.7520e-04 - val_loss: 0.0559
# Epoch 175/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 4.8361e-04 - val_loss: 0.0312
# Epoch 176/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.8279e-04 - val_loss: 0.0239
# Epoch 177/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 4.7615e-04 - val_loss: 0.0187
# Epoch 178/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 4.3502e-04 - val_loss: 0.0199
# Epoch 179/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.6400e-04 - val_loss: 0.0185
# Epoch 180/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.3491e-04 - val_loss: 0.0168
# Epoch 181/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.0796e-04 - val_loss: 0.0156
# Epoch 182/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 4.6712e-04 - val_loss: 0.0112
# Epoch 183/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 4.8647e-04 - val_loss: 0.0114
# Epoch 184/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.6122e-04 - val_loss: 0.0111
# Epoch 185/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 3.2136e-04 - val_loss: 0.0130
# Epoch 186/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.6159e-04 - val_loss: 0.0188
# Epoch 187/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.9499e-04 - val_loss: 0.0178
# Epoch 188/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.3207e-04 - val_loss: 0.0144
# Epoch 189/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.3586e-04 - val_loss: 0.0128
# Epoch 190/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.7034e-04 - val_loss: 0.0108
# Epoch 191/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.2910e-04 - val_loss: 0.0109
# Epoch 192/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.7352e-04 - val_loss: 0.0109
# Epoch 193/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 2.2776e-04 - val_loss: 0.0088
# Epoch 194/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.0544e-04 - val_loss: 0.0076
# Epoch 195/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.6571e-04 - val_loss: 0.0089
# Epoch 196/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.3226e-04 - val_loss: 0.0090
# Epoch 197/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 4.4831e-04 - val_loss: 0.0095
# Epoch 198/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.9349e-04 - val_loss: 0.0073
# Epoch 199/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.2171e-04 - val_loss: 0.0068
# Epoch 200/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.2268e-04 - val_loss: 0.0068
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# MAE: 916044.3542, RMSE: 1095835.3126, R2: -8.8794
# 실제값과 예측값 비교 (LSTM):
#              실제 수출량   예측 수출량
# date
# 2023-01-01  7228875  8978259
# 2023-02-01  7632714  9532217
# 2023-03-01  8154789  9833164
# 2023-04-01  7763702  9134044
# 2023-05-01  8065084  9058639
# 2023-06-01  7471674  8865440
# 2023-07-01  7583791  8768284
# 2023-08-01  7220254  9089295
# 2023-09-01  8096833  9056319
# 2023-10-01  7275659  8486812
# 2023-11-01  7950808  8099548
# 2023-12-01  7589665  7759754
# 2024-01-01  7405154  7550556
# 2024-02-01  7369250  7384538
# 2024-03-01  8317543  7075976
# 2024-04-01  7901292  6869997
# 2024-05-01  7829182  6749063
# 2024-06-01  7926650  6695364
# 2024-07-01  8211286  7047660
# 2024-08-01  7602667  7024839
# 2024-09-01  6946622  7213698
# 2024-10-01  8004480  7761810
# 2024-11-01  7556141  7726286
# 2024-12-01  7696030  7886863
